# %%
from qdrant_client import QdrantClient
from qdrant_client.models import Distance, VectorParams, PointStruct

import pandas as pd

# %%
qdrant_client = QdrantClient(url="http://localhost:6333")

qdrant_client.create_collection(
    collection_name="mpv_dataset_farmaci",
    vectors_config=VectorParams(size=1536, distance=Distance.COSINE),
)
# Out:
# ---------------------------------------------------------------------------
# UnexpectedResponse                        Traceback (most recent call last)
# Cell In[5], line 3
#       1 qdrant_client = QdrantClient(url="http://localhost:6333")
# ----> 3 qdrant_client.create_collection(
#       4     collection_name="mpv_dataset_farmaci",
#       5     vectors_config=VectorParams(size=1536, distance=Distance.COSINE),
#       6 )
#
# File ~/Documents/ai_bootcamp/project_1/aiengineeringbootcamp/.venv/lib/python3.12/site-packages/qdrant_client/qdrant_client.py:2382, in QdrantClient.create_collection(self, collection_name, vectors_config, sparse_vectors_config, shard_number, sharding_method, replication_factor, write_consistency_factor, on_disk_payload, hnsw_config, optimizers_config, wal_config, quantization_config, init_from, timeout, strict_mode_config, **kwargs)
#    2332 """Create empty collection with given parameters
#    2333
#    2334 Args:
#    (...)   2378     Operation result
#    2379 """
#    2380 assert len(kwargs) == 0, f"Unknown arguments: {list(kwargs.keys())}"
# -> 2382 return self._client.create_collection(
#    2383     collection_name=collection_name,
#    2384     vectors_config=vectors_config,
#    2385     shard_number=shard_number,
#    2386     sharding_method=sharding_method,
#    2387     replication_factor=replication_factor,
#    2388     write_consistency_factor=write_consistency_factor,
#    2389     on_disk_payload=on_disk_payload,
#    2390     hnsw_config=hnsw_config,
#    2391     optimizers_config=optimizers_config,
#    2392     wal_config=wal_config,
#    2393     quantization_config=quantization_config,
#    2394     init_from=init_from,
#    2395     timeout=timeout,
#    2396     sparse_vectors_config=sparse_vectors_config,
#    2397     strict_mode_config=strict_mode_config,
#    2398     **kwargs,
#    2399 )
#
# File ~/Documents/ai_bootcamp/project_1/aiengineeringbootcamp/.venv/lib/python3.12/site-packages/qdrant_client/qdrant_remote.py:2815, in QdrantRemote.create_collection(self, collection_name, vectors_config, shard_number, replication_factor, write_consistency_factor, on_disk_payload, hnsw_config, optimizers_config, wal_config, quantization_config, init_from, timeout, sparse_vectors_config, sharding_method, strict_mode_config, **kwargs)
#    2797     init_from = GrpcToRest.convert_init_from(init_from)
#    2799 create_collection_request = models.CreateCollection(
#    2800     vectors=vectors_config,
#    2801     shard_number=shard_number,
#    (...)   2812     strict_mode_config=strict_mode_config,
#    2813 )
# -> 2815 result: Optional[bool] = self.http.collections_api.create_collection(
#    2816     collection_name=collection_name,
#    2817     create_collection=create_collection_request,
#    2818     timeout=timeout,
#    2819 ).result
#    2821 assert result is not None, "Create collection returned None"
#    2822 return result
#
# File ~/Documents/ai_bootcamp/project_1/aiengineeringbootcamp/.venv/lib/python3.12/site-packages/qdrant_client/http/api/collections_api.py:294, in SyncCollectionsApi.create_collection(self, collection_name, timeout, create_collection)
#     285 def create_collection(
#     286     self,
#     287     collection_name: str,
#     288     timeout: int = None,
#     289     create_collection: m.CreateCollection = None,
#     290 ) -> m.InlineResponse200:
#     291     """
#     292     Create new collection with given parameters
#     293     """
# --> 294     return self._build_for_create_collection(
#     295         collection_name=collection_name,
#     296         timeout=timeout,
#     297         create_collection=create_collection,
#     298     )
#
# File ~/Documents/ai_bootcamp/project_1/aiengineeringbootcamp/.venv/lib/python3.12/site-packages/qdrant_client/http/api/collections_api.py:96, in _CollectionsApi._build_for_create_collection(self, collection_name, timeout, create_collection)
#      94 if "Content-Type" not in headers:
#      95     headers["Content-Type"] = "application/json"
# ---> 96 return self.api_client.request(
#      97     type_=m.InlineResponse200,
#      98     method="PUT",
#      99     url="/collections/{collection_name}",
#     100     headers=headers if headers else None,
#     101     path_params=path_params,
#     102     params=query_params,
#     103     content=body,
#     104 )
#
# File ~/Documents/ai_bootcamp/project_1/aiengineeringbootcamp/.venv/lib/python3.12/site-packages/qdrant_client/http/api_client.py:95, in ApiClient.request(self, type_, method, url, path_params, **kwargs)
#      93     kwargs["timeout"] = int(kwargs["params"]["timeout"])
#      94 request = self._client.build_request(method, url, **kwargs)
# ---> 95 return self.send(request, type_)
#
# File ~/Documents/ai_bootcamp/project_1/aiengineeringbootcamp/.venv/lib/python3.12/site-packages/qdrant_client/http/api_client.py:130, in ApiClient.send(self, request, type_)
#     128     except ValidationError as e:
#     129         raise ResponseHandlingException(e)
# --> 130 raise UnexpectedResponse.for_response(response)
#
# UnexpectedResponse: Unexpected Response: 409 (Conflict)
# Raw response content:
# b'{"status":{"error":"Wrong input: Collection `mpv_dataset_farmaci` already exists!"},"time":0.000238541}'

# %%
df_items = pd.read_json("/Users/enzomariasavelli/Documents/ai_bootcamp/project_1/aiengineeringbootcamp/data/output/mvp_dataset.json")

# %%
df_items.head(2)
# Out:
#    FDI_0001                     FDI_0004 FDI_0008 FDI_0329  FDI_0339  \
# 0    367058  TISANA KELEMATA*OS POLV 80G        D  A06AB06    340800
# 1    367072  TISANA KELEMATA*20BUST 1,3G        D  A06AB06    340800
#
#    FDI_0456                                      DENOMINAZIONE  \
# 0      1041  TISANA KEL&Egrave;MATA &ldquo;POLVERE PER TISA...
# 1      1041                                    TISANA KELEMATA
#
#                                           ECCIPIENTI  \
# 0  Gramigna, guaiaco, issopo, parietaria, menta p...
# 1  Gramigna, guaiaco, issopo, parietaria, menta p...
#
#                                 DESCRIZIONE_GENERALE CODICE_ICD  \
# 0  Trattamento di breve durata della stitichezza ...       None
# 1  Trattamento di breve durata della stitichezza ...       None
#
#   DESCRIZIONE_ICD DESTINAZIONE_USO  \
# 0            None             None
# 1            None             None
#
#                                     PRINCIPIO_ATTIVO
# 0  SENNA FOGLIE-100 g contengono: <b>Principio at...
# 1  SENNA FOGLIE-Ogni bustina contiene: <table bor...

# %%
def preprocess_data(row):
    return f"{row['FDI_0004']} {row['ECCIPIENTI']} {row['DESCRIZIONE_GENERALE']}{row['PRINCIPIO_ATTIVO']}{row['DESCRIZIONE_ICD']}"

# %%
df_items['preprocessed_data'] = df_items.apply(preprocess_data, axis=1)

# %%
df_items.head(2)
# Out:
#    FDI_0001                     FDI_0004 FDI_0008 FDI_0329  FDI_0339  \
# 0    367058  TISANA KELEMATA*OS POLV 80G        D  A06AB06    340800
# 1    367072  TISANA KELEMATA*20BUST 1,3G        D  A06AB06    340800
#
#    FDI_0456                                      DENOMINAZIONE  \
# 0      1041  TISANA KEL&Egrave;MATA &ldquo;POLVERE PER TISA...
# 1      1041                                    TISANA KELEMATA
#
#                                           ECCIPIENTI  \
# 0  Gramigna, guaiaco, issopo, parietaria, menta p...
# 1  Gramigna, guaiaco, issopo, parietaria, menta p...
#
#                                 DESCRIZIONE_GENERALE CODICE_ICD  \
# 0  Trattamento di breve durata della stitichezza ...       None
# 1  Trattamento di breve durata della stitichezza ...       None
#
#   DESCRIZIONE_ICD DESTINAZIONE_USO  \
# 0            None             None
# 1            None             None
#
#                                     PRINCIPIO_ATTIVO  \
# 0  SENNA FOGLIE-100 g contengono: <b>Principio at...
# 1  SENNA FOGLIE-Ogni bustina contiene: <table bor...
#
#                                    preprocessed_data
# 0  TISANA KELEMATA*OS POLV 80G Gramigna, guaiaco,...
# 1  TISANA KELEMATA*20BUST 1,3G Gramigna, guaiaco,...

# %%
import tiktoken

def num_tokens_from_string(string: str, model_name: str = "text-embedding-3-small") -> int:
    encoding = tiktoken.encoding_for_model(model_name)
    return len(encoding.encode(string))

# %%
tokens = []
for i in range(len(df_items)):
    tokens.append(num_tokens_from_string(df_items['preprocessed_data'].iloc[i], "text-embedding-3-small"))


print(tokens[0:10])
# Out:
# [1037, 1168, 1016, 798, 898, 895, 753, 886, 1319, 1360]

# %%
index_allowed_tokens = [i for i in range(len(tokens)) if tokens[i] < 6000]
print(len(index_allowed_tokens))
# Out:
# 187073

# %%
df_filtered = df_items.iloc[index_allowed_tokens]
print(len(df_filtered))
# Out:
# 187073

# %%
df_sample = df_filtered.sample(n=50,random_state=55)

# %%
import openai

def get_embeddings(text, model_name="text-embedding-3-small"):
    response = openai.embeddings.create(
        input = [text],
        model = model_name
    )
    return response.data[0].embedding

# %%
data_to_embed = df_sample['preprocessed_data'].tolist()

pointstructs = []
for i,data in enumerate(data_to_embed):
    embedding = get_embeddings(data)
    pointstructs.append(PointStruct(id=i, vector=embedding, payload={"text": data}))

# %%
pointstructs
# Out:
# [PointStruct(id=0, vector=[0.00851596612483263, 0.017380012199282646, 0.04412218555808067, 0.05161191523075104, -0.0366564616560936, -0.006865585222840309, -0.01575963757932186, -0.0033517738338559866, -0.016179734840989113, -0.05458860471844673, 0.015291530638933182, -0.03766469657421112, 0.0019114413298666477, 0.02071678265929222, 0.04815511777997017, -0.015615604817867279, 0.00832392182201147, -0.01769208535552025, 0.010034316219389439, 0.008203893899917603, 0.04582658037543297, -0.01808817684650421, -0.04181765392422676, -0.060686010867357254, -0.0006211433792486787, -0.0673595517873764, 0.008822036907076836, -0.044074174016714096, -0.007891821675002575, -0.030559055507183075, 0.014835424721240997, -0.04040132835507393, 0.01578364335000515, -0.029238751158118248, 0.04306594282388687, -0.007147650234401226, 0.00945818331092596, 0.009626222774386406, -0.044962380081415176, -0.05281219258904457, -0.013491114601492882, 0.00529022142291069, 0.030751099810004234, 0.0518999807536602, -0.006040394771844149, -0.006193429697304964, 0.01557959709316492, 0.01982857845723629, 0.02578195184469223, -0.015183505602180958, -0.025349853560328484, 0.013287067413330078, -0.01487143337726593, 0.03656044229865074, -0.02351342886686325, -0.03713657334446907, 0.021532971411943436, 0.028230518102645874, 0.005098177120089531, 0.0034267911687493324, -0.006589521188288927, -0.03591229021549225, 0.02296130172908306, 0.015255521982908249, -0.06044595688581467, -0.016683852300047874, 0.009572209790349007, -0.01200277078896761, -0.004543048795312643, -0.0216049887239933, -0.02281726710498333, 0.02376548759639263, 0.02508579194545746, 0.03231145814061165, -0.03857690468430519, 0.008587982505559921, 0.01880834251642227, -0.05574087053537369, 0.01595168374478817, -0.012338848784565926, -0.012674926780164242, 0.05574087053537369, -0.05017158389091492, -0.031303226947784424, 0.04940340667963028, -0.03682450205087662, -0.0336797758936882, -0.008653998374938965, -0.009062091819941998, -0.005146188195794821, -0.03120720572769642, -0.0097462497651577, -0.013227053917944431, 0.028734633699059486, 0.005668308585882187, -0.013683158904314041, -0.008551974780857563, 0.050219595432281494, -0.04035331681370735, 0.026406096294522285, 0.023465417325496674, 0.0010592445032671094, 0.016887899488210678, -0.022481190040707588, 0.021580982953310013, 0.0667354092001915, -0.07302486151456833, -0.0010922522051259875, 0.01532753836363554, 0.01186473947018385, 0.047314923256635666, -0.011342618614435196, -0.018436256796121597, -0.002453066408634186, -0.00
# %%
qdrant_client = QdrantClient(url="http://localhost:6333")

qdrant_client.create_collection(
    collection_name="dataset_farmaci_2",
    vectors_config=VectorParams(size=1536, distance=Distance.COSINE),
)
# Out:
# ---------------------------------------------------------------------------
# UnexpectedResponse                        Traceback (most recent call last)
# Cell In[22], line 3
#       1 qdrant_client = QdrantClient(url="http://localhost:6333")
# ----> 3 qdrant_client.create_collection(
#       4     collection_name="dataset_farmaci_2",
#       5     vectors_config=VectorParams(size=1536, distance=Distance.COSINE),
#       6 )
#
# File ~/Documents/ai_bootcamp/project_1/aiengineeringbootcamp/.venv/lib/python3.12/site-packages/qdrant_client/qdrant_client.py:2382, in QdrantClient.create_collection(self, collection_name, vectors_config, sparse_vectors_config, shard_number, sharding_method, replication_factor, write_consistency_factor, on_disk_payload, hnsw_config, optimizers_config, wal_config, quantization_config, init_from, timeout, strict_mode_config, **kwargs)
#    2332 """Create empty collection with given parameters
#    2333
#    2334 Args:
#    (...)   2378     Operation result
#    2379 """
#    2380 assert len(kwargs) == 0, f"Unknown arguments: {list(kwargs.keys())}"
# -> 2382 return self._client.create_collection(
#    2383     collection_name=collection_name,
#    2384     vectors_config=vectors_config,
#    2385     shard_number=shard_number,
#    2386     sharding_method=sharding_method,
#    2387     replication_factor=replication_factor,
#    2388     write_consistency_factor=write_consistency_factor,
#    2389     on_disk_payload=on_disk_payload,
#    2390     hnsw_config=hnsw_config,
#    2391     optimizers_config=optimizers_config,
#    2392     wal_config=wal_config,
#    2393     quantization_config=quantization_config,
#    2394     init_from=init_from,
#    2395     timeout=timeout,
#    2396     sparse_vectors_config=sparse_vectors_config,
#    2397     strict_mode_config=strict_mode_config,
#    2398     **kwargs,
#    2399 )
#
# File ~/Documents/ai_bootcamp/project_1/aiengineeringbootcamp/.venv/lib/python3.12/site-packages/qdrant_client/qdrant_remote.py:2815, in QdrantRemote.create_collection(self, collection_name, vectors_config, shard_number, replication_factor, write_consistency_factor, on_disk_payload, hnsw_config, optimizers_config, wal_config, quantization_config, init_from, timeout, sparse_vectors_config, sharding_method, strict_mode_config, **kwargs)
#    2797     init_from = GrpcToRest.convert_init_from(init_from)
#    2799 create_collection_request = models.CreateCollection(
#    2800     vectors=vectors_config,
#    2801     shard_number=shard_number,
#    (...)   2812     strict_mode_config=strict_mode_config,
#    2813 )
# -> 2815 result: Optional[bool] = self.http.collections_api.create_collection(
#    2816     collection_name=collection_name,
#    2817     create_collection=create_collection_request,
#    2818     timeout=timeout,
#    2819 ).result
#    2821 assert result is not None, "Create collection returned None"
#    2822 return result
#
# File ~/Documents/ai_bootcamp/project_1/aiengineeringbootcamp/.venv/lib/python3.12/site-packages/qdrant_client/http/api/collections_api.py:294, in SyncCollectionsApi.create_collection(self, collection_name, timeout, create_collection)
#     285 def create_collection(
#     286     self,
#     287     collection_name: str,
#     288     timeout: int = None,
#     289     create_collection: m.CreateCollection = None,
#     290 ) -> m.InlineResponse200:
#     291     """
#     292     Create new collection with given parameters
#     293     """
# --> 294     return self._build_for_create_collection(
#     295         collection_name=collection_name,
#     296         timeout=timeout,
#     297         create_collection=create_collection,
#     298     )
#
# File ~/Documents/ai_bootcamp/project_1/aiengineeringbootcamp/.venv/lib/python3.12/site-packages/qdrant_client/http/api/collections_api.py:96, in _CollectionsApi._build_for_create_collection(self, collection_name, timeout, create_collection)
#      94 if "Content-Type" not in headers:
#      95     headers["Content-Type"] = "application/json"
# ---> 96 return self.api_client.request(
#      97     type_=m.InlineResponse200,
#      98     method="PUT",
#      99     url="/collections/{collection_name}",
#     100     headers=headers if headers else None,
#     101     path_params=path_params,
#     102     params=query_params,
#     103     content=body,
#     104 )
#
# File ~/Documents/ai_bootcamp/project_1/aiengineeringbootcamp/.venv/lib/python3.12/site-packages/qdrant_client/http/api_client.py:95, in ApiClient.request(self, type_, method, url, path_params, **kwargs)
#      93     kwargs["timeout"] = int(kwargs["params"]["timeout"])
#      94 request = self._client.build_request(method, url, **kwargs)
# ---> 95 return self.send(request, type_)
#
# File ~/Documents/ai_bootcamp/project_1/aiengineeringbootcamp/.venv/lib/python3.12/site-packages/qdrant_client/http/api_client.py:130, in ApiClient.send(self, request, type_)
#     128     except ValidationError as e:
#     129         raise ResponseHandlingException(e)
# --> 130 raise UnexpectedResponse.for_response(response)
#
# UnexpectedResponse: Unexpected Response: 409 (Conflict)
# Raw response content:
# b'{"status":{"error":"Wrong input: Collection `dataset_farmaci_2` already exists!"},"time":0.0000665}'

# %%
df_sample = df_items.sample(n=50, random_state=25)

# %%
def get_embeddings(text, model_name="text-embedding-3-small"):
    response = openai.embeddings.create(
        input = [text],
        model = model_name
    )
    return response.data[0].embedding

# %%
data_to_embed = df_sample['preprocessed_data'].tolist()

pointstructs = []
for i,data in enumerate(data_to_embed):
    embedding = get_embeddings(data)
    pointstructs.append(PointStruct(id=i, vector=embedding, payload={"text": data}))

# %%
qdrant_client.upsert(
    collection_name="dataset_farmaci_2",
    wait=True,
    points=pointstructs
)
# Out:
# UpdateResult(operation_id=1, status=<UpdateStatus.COMPLETED: 'completed'>)

# %%
import json

output_schema = {
    "type": "array",
    "items": {
        "type": "object",
        "properties": {
            "question": {
                "type": "string",
                "description": "Suggested question.",
            },
            "chunk_ids": {
                "type": "array",
                "items": {
                    "type": "integer",
                    "description": "Index of the chunk that could be used to answer the question.",
                },
            },
            "answer_example": {
                "type": "string",
                "description": "Suggested answer grounded in the contexr.",
            },
            "reasoning": {
                "type": "string",
                "description": "Reasoning why the question could be answered with the chunks.",
            },
        },
    },
}


SYSTEM_PROMPT = f"""
I am building a RAG application. I have a collection of 50 chunks of text. 
The RAG application will act as a pharmacist assistant who can answer questions about which medicines to use for a specific condition.
I will provide you with all of the available medicines with indexes of each chunk.
I want you to come up with 30 questions to which the answers will be grounded in the chunks context.
As an output I need you to provide me with a list of questions and the index of the chunk that could be used to answer the question.
Also, provide an example answer to the question given the context of the chunks.
Also, provide the reason why you chose those chunks to answer the question.
Try to come up with a mix of questions that could use multiple chunks and questions that could use a single chunk.
Also, include 5 questions that can't be answered with the available chunks.

{json.dumps(output_schema, indent=2)}

I need to be able to parse the json output.
"""

USER_PROMPT = f"""
Here is the list of chunks. Each list element is a dictionary with id and text.
{[{"id": i, "text": data} for i, data in enumerate(data_to_embed)]}
"""

# %%
print(SYSTEM_PROMPT)
# Out:
# I am building a RAG application. I have a collection of 50 chunks of text.
# The RAG application will act as a pharmacist assistant who can answer questions about which medicines to use for a specific condition.
# I will provide you with all of the available medicines with indexes of each chunk.
# I want you to come up with 30 questions to which the answers will be grounded in the chunks context.
# As an output I need you to provide me with a list of questions and the index of the chunk that could be used to answer the question.
# Also, provide an example answer to the question given the context of the chunks.
# Also, provide the reason why you chose those chunks to answer the question.
# Try to come up with a mix of questions that could use multiple chunks and questions that could use a single chunk.
# Also, include 5 questions that can't be answered with the available chunks.
#
# {
#   "type": "array",
#   "items": {
#     "type": "object",
#     "properties": {
#       "question": {
#         "type": "string",
#         "description": "Suggested question."
#       },
#       "chunk_ids": {
#         "type": "array",
#         "items": {
#           "type": "integer",
#           "description": "Index of the chunk that could be used to answer the question."
#         }
#       },
#       "answer_example": {
#         "type": "string",
#         "description": "Suggested answer grounded in the contexr."
#       },
#       "reasoning": {
#         "type": "string",
#         "description": "Reasoning why the question could be answered with the chunks."
#       }
#     }
#   }
# }
#
# I need to be able to parse the json output.

# %%
print(USER_PROMPT)
# Out:
# Here is the list of chunks. Each list element is a dictionary with id and text.
# [{'id': 0, 'text': 'CALCAREA CARBON 200CH GR 4G None br>Medicinale omeopatico senza  indicazioni terapeutiche approvateNESSUN PRINCIPIO ATTIVO-nanNone'}, {'id': 1, 'text': "AGLIO COMP 50CPS 29,5G None br> <font size=2><b>HEALTH</b></font><br> <br> <font size=5>Aglio<br> composto</font><br> <br> <font size=2>Integratore alimentare<br> a base di estratti vegetali</font><br> <br> <div align=justify>Il prodotto favorisce:<br> &bull; la regolare funzionalit&agrave; dell'apparato cardiovascolare;<br> &bull; la regolarit&agrave; della pressione arteriosa. <br> <br> <b>Ingredienti</b><br> Aglio bulbo (<i>Allium sativum</i>) estratto secco titolato all'1% alliina, Biancospino fiori e foglie (<i>Crataegus oxiacantha</i>) estratto secco titolato 1,5% vitexina, Ulivo foglie (<i>Olea europaea</i>) estratto secco titolato 6% oleuropeina.<br> Coadiuvanti: talco.<br> Capsule in gelatina vegetale.<br> Non contiene coloranti, conservanti, aromi artificiali, OGM.<br> Prodotto di origine vegetale adatto a vegani e vegetariani.<br> <br> <b>Modalit&agrave; d'uso</b><br> 3 capsule al giorno, prima dei pasti.<br> <br> <b>Avvertenze</b><br> Non eccedere la dose giornaliera consigliata. Tenere fuori dalla portata dei bambini di et&agrave; inferiore ai 3 anni. Gli integratori alimentari non vanno intesi come sostituti di una dieta variata e di uno stile di vita sano. Per donne in gravidanza e in allattamento, sentire il parere del medico. <br> <br> <b>Conservazione</b><br> Conservare in un luogo fresco ed asciutto.<br> <br> <b>Formato</b><br> 50 capsule.</div>NESSUN PRINCIPIO ATTIVO-nanNone"}, {'id': 2, 'text': 'FISIO KIT IDRATAZIONE 3PZ None h1>KIT IDRATAZIONE</h1> <div align="justify"> <b>Descrizione</b><br> <u>SHAMPOO CAPELLI DA IDRATARE</u>: Shampoo idratante a base di aloe vera. Particolarmente indicato nei casi di capelli sfibrati e secchi.<br> Riporta cute e capelli all\'ottimale livello di idratazione.<br> <br> <u>MASCHERA CAPELLI DA IDRATARE</u>: Maschera idratante particolarmente indicata nei casi di capelli sfibrati, secchi o trattati chimicamente.<br> <br> <u>PROFUMO PER CAPELLI</u>: Prodotto che lucida e profuma i capelli anche non lavati.<br> <br> <b>Modalit&agrave; d\'uso</b><br> <u>SHAMPOO CAPELLI DA IDRATARE</u>: Applicare lo shampoo su tutta la capigliatura e con aggiunta di poca acqua emulsionarlo. Risciacquare.<br> <br> <u>MASCHERA CAPELLI DA IDRATARE</u>: Dopo lo shampoo, applicare il prodotto su tutta la capigliatura distribuendolo uniformemente. Pettinare con cura e risciacquare.<br> <br> <u>PROFUMO PER CAPELLI</u>: Vaporizzare sopra la testa e non direttamente sui capelli. Attendere alcuni secondi. Non risciacquare.<br> <br> <b>Conservazione</b><br> Conservare ad una temperatura da 15 &deg;C a 20 &deg;C.<br> Validit&agrave; post-apertura: 12 mesi.<br> <br> <b>Formato</b><br> Il kit contiene:<br> - SHAMPOO CAPELLI DA IDRATARE: 260 g;<br> - MASCHERA CAPELLI DA IDRATARE: 270 g;<br> - PROFUMO PER CAPELLI: 50 g.</div>NESSUN PRINCIPIO ATTIVO-nanNone'}, {'id': 3, 'text': "XALOST*COLL 1FL 2,5ML 50MCG/ML Sodio cloruro, Benzalconio cloruro, Sodio fosfato monobasico monoidrato, Sodio fosfato dibasico anidro, Acqua per preparazioni iniettabili. Riduzione della pressione intraoculare elevata in pazienti con glaucoma ad angolo aperto e in pazienti con ipertensione oculare.Riduzione della pressione intraoculare elevata in pazienti pediatrici con elevata pressione intraoculare e in pazienti con glaucoma pediatrico. Ipersensibilit&agrave; al principio attivo o ad uno qualsiasi degli eccipienti di Xalost elencati in sezione 6.1. Uso oftalmico. <i>Dose raccomandata negli adulti (inclusi pazienti anziani):</i> La terapia raccomandata &egrave; una goccia una volta al giorno nell'occhio(i) da trattare. L'effetto ottimale si ottiene somministrando Xalost alla sera. Non instillare la dose di Xalost pi&ugrave; di una volta al giorno, in quanto &egrave; stato dimostrato che somministrazioni pi&ugrave; frequenti diminuiscono l'effetto ipotensivo sulla pres ...

# %%
response = openai.chat.completions.create(
    model="gpt-4.1",
    messages=[
        {"role": "system", "content": SYSTEM_PROMPT},
        {"role": "user", "content": USER_PROMPT}
    ]
)

print(response.choices[0].message.content)
# Out:
# ```json
# [
#   {
#     "question": "Qual è il medicinale consigliato come coadiuvante per la funzionalità epatica?",
#     "chunk_ids": [26],
#     "answer_example": "Il prodotto FEGATO 250G è un integratore alimentare con carciofo, le cui foglie coadiuvano la funzione epatica.",
#     "reasoning": "Il chunk 26 descrive un prodotto specifico per la funzione epatica a base di estratti di carciofo."
#   },
#   {
#     "question": "Cosa è consigliato per favorire l'equilibrio del peso corporeo e il controllo del senso di fame?",
#     "chunk_ids": [10, 46],
#     "answer_example": "Entrambi Kiloburn Forte e Inverter Control P sono utili per l’equilibrio del peso corporeo e il controllo del senso di fame, grazie a ingredienti come opuntia, garcinia cambogia e griffonia.",
#     "reasoning": "Entrambi i chunk 10 e 46 descrivono integratori utili per il controllo del peso e della fame."
#   },
#   {
#     "question": "Quale prodotto aiuta a ridurre la pressione intraoculare nei pazienti con glaucoma?",
#     "chunk_ids": [3],
#     "answer_example": "XALOST*COLL è indicato per la riduzione della pressione intraoculare elevata nei pazienti con glaucoma ad angolo aperto.",
#     "reasoning": "Il chunk 3 tratta nello specifico della riduzione della pressione intraoculare tramite XALOST*COLL."
#   },
#   {
#     "question": "Quali sono le avvertenze sull'uso di integratori per abbassare il colesterolo contenenti riso rosso fermentato?",
#     "chunk_ids": [45],
#     "answer_example": "Il prodotto non deve essere consumato se si assumono già medicinali per abbassare il colesterolo o se si consumano altri prodotti al riso rosso fermentato. È controindicato in gravidanza, allattamento, nei bambini e negli adulti sopra i 70 anni.",
#     "reasoning": "Il chunk 45 specifica le avvertenze relative agli integratori a base di riso rosso fermentato."
#   },
#   {
#     "question": "Che integratore si consiglia come supporto naturale per la pressione arteriosa e la funzionalità cardiovascolare?",
#     "chunk_ids": [1],
#     "answer_example": "AGLIO COMP favorisce la regolare funzionalità dell'apparato cardiovascolare e la regolarità della pressione arteriosa.",
#     "reasoning": "Il chunk 1 descrive un integratore a base di aglio pensato per il supporto cardiovascolare e della pressione sanguigna."
#   },
#   {
#     "question": "Quale medicinale può aiutare contro l'affaticamento e gli inestetismi delle gambe?",
#     "chunk_ids": [6],
#     "answer_example": "ERAVEN CREMA VASOTONICA allevia l’affaticamento e attenua gli inestetismi cutanei degli arti inferiori, migliorando il microcircolo.",
#     "reasoning": "Chunk 6 dettaglia un prodotto specifico per questi problemi."
#   },
#   {
#     "question": "Cosa si può utilizzare nei casi di secchezza o desquamazione cutanea del viso?",
#     "chunk_ids": [14, 44],
#     "answer_example": "Australian BC Squalane Serum, grazie allo squalano e tea tree oil, è particolarmente indicato per pelli secche e sensibili. Il siero viso acido jaluronico di Medicallife idrata e trattiene l'acqua nella pelle, aiutando contro la disidratazione.",
#     "reasoning": "Chunks 14 e 44 presentano prodotti rispettivamente a base di squalano e acido ialuronico per la secchezza cutanea."
#   },
#   {
#     "question": "Quale prodotto si consiglia in caso di capelli sfibrati e secchi che necessitano di idratazione?",
#     "chunk_ids": [2],
#     "answer_example": "Il FISIO KIT IDRATAZIONE contiene uno shampoo e una maschera specificamente formulati per idratare capelli secchi e sfibrati.",
#     "reasoning": "Chunk 2 descrive un kit dedicato all’idratazione dei capelli."
#   },
#   {
#     "question": "Che rimedio naturale è indicato per la fluidità delle secrezioni bronchiali?",
#     "chunk_ids": [17],
#     "answer_example": "TUX J 200ML, a base di sambuco e timo, è indicato per favorire la fluidità delle secrezioni bronchiali.",
#     "reasoning": "Chunk 17 cita ingredienti ad azione balsamica e fluidificante."
#   },
#   {
#     "question": "Quale integratore può essere assunto per integrare magnesio, potassio e calcio?",
#     "chunk_ids": [41],
#     "answer_example": "KEYMINERAL è un integratore alimentare che fornisce magnesio, potassio e calcio.",
#     "reasoning": "Chunk 41 riporta queste indicazioni."
#   },
#   {
#     "question": "Quali integratori sono adatti per il metabolismo dei lipidi?",
#     "chunk_ids": [10, 45, 46],
#     "answer_example": "Kiloburn Forte, Coleterol Act Plus Forte e Inverter Control P favoriscono il metabolismo lipidico tramite ingredienti come yerba mate, guggul e cassia nomame.",
#     "reasoning": "I chunk 10, 45 e 46 riportano claim relativi al metabolismo lipidico."
#   },
#   {
#     "question": "Come si può trattare in modo naturale l'insonnia o favorire il rilassamento?",
#     "chunk_ids": [20],
#     "answer_example": "PULVISED contiene passiflora, escolzia e griffonia, utili per favorire rilassamento e regolare il sonno.",
#     "reasoning": "Chunk 20 contiene formule vegetali per rilassamento e sonno."
#   },
#   {
#     "question": "Che integratore a base vegetale può aiutare la funzionalità digestiva?",
#     "chunk_ids": [10],
#     "answer_example": "Kiloburn Forte contiene magnolia e opuntia, utili per la funzione digestiva e per favorire la digestione.",
#     "reasoning": "Chunk 10 menziona funzioni digestive."
#   },
#   {
#     "question": "Quale prodotto contiene diosmina ed estratti di ippocastano per la circolazione?",
#     "chunk_ids": [6],
#     "answer_example": "ERAVEN CREMA VASOTONICA contiene diosmina, insieme a estratti di ippocastano e altri componenti, per il benessere della circolazione.",
#     "reasoning": "Chunk 6 elenca diosmina e ippocastano tra i componenti."
#   },
#   {
#     "question": "Quale prodotto è indicato come coadiuvante nel trattamento delle ipercromie cutanee?",
#     "chunk_ids": [39],
#     "answer_example": "DISCROMIL PLUS CR è una crema schiarente indicata per risolvere rapidamente le ipercromie cutanee.",
#     "reasoning": "Chunk 39 spiega l’indicazione schiarente sulle ipercromie."
#   },
#   {
#     "question": "Per quali condizioni è sconsigliato l'utilizzo di Xalost*coll?",
#     "chunk_ids": [3],
#     "answer_example": "Xalost non deve essere utilizzato in gravidanza, durante l’allattamento e in caso di ipersensibilità ai suoi componenti.",
#     "reasoning": "Chunk 3 elenca le controindicazioni all’uso del farmaco."
#   },
#   {
#     "question": "Quale integratore contiene vitamina C ad alto dosaggio e palmitoiletanolamide?",
#     "chunk_ids": [29],
#     "answer_example": "Sulfo24 30BUST contiene vitamina C (600 mg per dose) e palmitoiletanolamide.",
#     "reasoning": "Chunk 29 formula integratore con questi principi."
#   },
#   {
#     "question": "Che prodotto è suggerito per lenire fastidi durante il ciclo mestruale in modo naturale?",
#     "chunk_ids": [5],
#     "answer_example": "Compressa Spa Mensile dona sollievo e benessere durante il ciclo mestruale grazie all'aloe vera calmante.",
#     "reasoning": "Chunk 5 indirizzato al sollievo durante ciclo mestruale."
#   },
#   {
#     "question": "Quale prodotto per l’igiene intima contiene Tea Tree Oil?",
#     "chunk_ids": [15],
#     "answer_example": "AMIDOSAN II NAT INTIMO PH ACID contiene Tea Tree Oil ed estratti di aloe e timo per detergere delicatamente le parti intime.",
#     "reasoning": "Chunk 15 riporta tea tree oil tra gli ingredienti."
#   },
#   {
#     "question": "Che integratore può essere utile come supporto di aminoacidi essenziali e vitamine?",
#     "chunk_ids": [47],
#     "answer_example": "RICOCELL 40CPR contiene vari aminoacidi essenziali, vitamina C, vitamina E e bioflavonoidi da agrumi.",
#     "reasoning": "Chunk 47 definisce la presenza di aminoacidi e vitamine."
#   },
#   {
#     "question": "Cosa si può usare in caso di capelli con forfora?",
#     "chunk_ids": [18],
#     "answer_example": "Lo Shampoo solido alla bardana è indicato per capelli con forfora grazie alle proprietà purificanti della bardana.",
#     "reasoning": "Chunk 18 descrive uno shampoo specifico per questa condizione."
#   },
#   {
#     "question": "Esiste un prodotto consigliato per la protezione delle gengive e della placca orale?",
#     "chunk_ids": [33],
#     "answer_example": "Il COLLUTTORIO PLUS è attivo contro la placca batterica e protegge efficacemente le gengive.",
#     "reasoning": "Chunk 33 lo riporta come claim principale."
#   },
#   {
#     "question": "Quale rimedio vegetale sostiene il microcircolo oculare?",
#     "chunk_ids": [24],
#     "answer_example": "LVS 30S EUPHRASIA OFFICIN COMP è un integratore alimentare a base di estratti idroalcolici, utile per favorire il trofismo del microcircolo a livello oculare.",
#     "reasoning": "Chunk 24 lo indica come scopo principale."
#   },
#   {
#     "question": "Che prodotto è adatto come sostituto del pane per chi soffre di celiachia?",
#     "chunk_ids": [22],
#     "answer_example": "Le GALLETTE RISO sono prodotte senza glutine e sono adatte come sostituto del pane per celiaci.",
#     "reasoning": "Chunk 22 riporta l’indicazione specifica."
#   },
#   {
#     "question": "Quale prodotto può essere usato dopo la detersione per idratare la pelle del viso?",
#     "chunk_ids": [16, 44],
#     "answer_example": "Il tonico con Hamamelis e Ruscus o il Siero viso acido jaluronico possono essere usati dopo la detersione per idratare la pelle.",
#     "reasoning": "Chunks 16 e 44 descrivono prodotti idratanti da utilizzare dopo la detersione."
#   },
#   {
#     "question": "Quale prodotto cosmetico offre una protezione solare elevata?",
#     "chunk_ids": [],
#     "answer_example": "Non vi sono prodotti nella raccolta che offrano una protezione solare specifica.",
#     "reasoning": "Nessuno dei chunk elenca protezione solare come claim."
#   },
#   {
#     "question": "Esiste un prodotto antiparassitario per uso veterinario nella collezione?",
#     "chunk_ids": [],
#     "answer_example": "Nella lista dei prodotti fornita non ci sono antiparassitari veterinari.",
#     "reasoning": "Esame di tutti i chunk e assenza di riferimenti veterinari o antiparassitari."
#   },
#   {
#     "question": "Quale medicinale è indicato per il trattamento di infezioni da candida vaginale?",
#     "chunk_ids": [],
#     "answer_example": "Non ci sono prodotti nella lista specifici per il trattamento di infezioni da candida vaginale.",
#     "reasoning": "Nessuno dei chunk parla di antimicotici o trattamenti per candida."
#   },
#   {
#     "question": "Quale integratore può essere consigliato per migliorare la memoria e la concentrazione?",
#     "chunk_ids": [],
#     "answer_example": "Nessun prodotto della lista ha come claim il miglioramento della memoria o della concentrazione.",
#     "reasoning": "Analisi di tutti i chunk senza trovare claim su memoria/concentrazione."
#   },
#   {
#     "question": "È presente un medicinale per la gestione dell’asma broncale?",
#     "chunk_ids": [],
#     "answer_example": "Nessun medicinale per l’asma broncale è presente tra i prodotti disponibili.",
#     "reasoning": "Non ci sono medicinali broncodilatatori o specifici per asma tra i chunk."
#   }
# ]
# ```

# %%
import json
json_output = response.choices[0].message.content
json_output = json_output.replace("```json", "")
json_output = json_output.replace("```", "")
json_output = json.loads(json_output)

# %%
json_output
# Out:
# [{'question': 'Qual è il medicinale consigliato come coadiuvante per la funzionalità epatica?',
#   'chunk_ids': [26],
#   'answer_example': 'Il prodotto FEGATO 250G è un integratore alimentare con carciofo, le cui foglie coadiuvano la funzione epatica.',
#   'reasoning': 'Il chunk 26 descrive un prodotto specifico per la funzione epatica a base di estratti di carciofo.'},
#  {'question': "Cosa è consigliato per favorire l'equilibrio del peso corporeo e il controllo del senso di fame?",
#   'chunk_ids': [10, 46],
#   'answer_example': 'Entrambi Kiloburn Forte e Inverter Control P sono utili per l’equilibrio del peso corporeo e il controllo del senso di fame, grazie a ingredienti come opuntia, garcinia cambogia e griffonia.',
#   'reasoning': 'Entrambi i chunk 10 e 46 descrivono integratori utili per il controllo del peso e della fame.'},
#  {'question': 'Quale prodotto aiuta a ridurre la pressione intraoculare nei pazienti con glaucoma?',
#   'chunk_ids': [3],
#   'answer_example': 'XALOST*COLL è indicato per la riduzione della pressione intraoculare elevata nei pazienti con glaucoma ad angolo aperto.',
#   'reasoning': 'Il chunk 3 tratta nello specifico della riduzione della pressione intraoculare tramite XALOST*COLL.'},
#  {'question': "Quali sono le avvertenze sull'uso di integratori per abbassare il colesterolo contenenti riso rosso fermentato?",
#   'chunk_ids': [45],
#   'answer_example': 'Il prodotto non deve essere consumato se si assumono già medicinali per abbassare il colesterolo o se si consumano altri prodotti al riso rosso fermentato. È controindicato in gravidanza, allattamento, nei bambini e negli adulti sopra i 70 anni.',
#   'reasoning': 'Il chunk 45 specifica le avvertenze relative agli integratori a base di riso rosso fermentato.'},
#  {'question': 'Che integratore si consiglia come supporto naturale per la pressione arteriosa e la funzionalità cardiovascolare?',
#   'chunk_ids': [1],
#   'answer_example': "AGLIO COMP favorisce la regolare funzionalità dell'apparato cardiovascolare e la regolarità della pressione arteriosa.",
#   'reasoning': 'Il chunk 1 descrive un integratore a base di aglio pensato per il supporto cardiovascolare e della pressione sanguigna.'},
#  {'question': "Quale medicinale può aiutare contro l'affaticamento e gli inestetismi delle gambe?",
#   'chunk_ids': [6],
#   'answer_example': 'ERAVEN CREMA VASOTONICA allevia l’affaticamento e attenua gli inestetismi cutanei degli arti inferiori, migliorando il microcircolo.',
#   'reasoning': 'Chunk 6 dettaglia un prodotto specifico per questi problemi.'},
#  {'question': 'Cosa si può utilizzare nei casi di secchezza o desquamazione cutanea del viso?',
#   'chunk_ids': [14, 44],
#   'answer_example': "Australian BC Squalane Serum, grazie allo squalano e tea tree oil, è particolarmente indicato per pelli secche e sensibili. Il siero viso acido jaluronico di Medicallife idrata e trattiene l'acqua nella pelle, aiutando contro la disidratazione.",
#   'reasoning': 'Chunks 14 e 44 presentano prodotti rispettivamente a base di squalano e acido ialuronico per la secchezza cutanea.'},
#  {'question': 'Quale prodotto si consiglia in caso di capelli sfibrati e secchi che necessitano di idratazione?',
#   'chunk_ids': [2],
#   'answer_example': 'Il FISIO KIT IDRATAZIONE contiene uno shampoo e una maschera specificamente formulati per idratare capelli secchi e sfibrati.',
#   'reasoning': 'Chunk 2 descrive un kit dedicato all’idratazione dei capelli.'},
#  {'question': 'Che rimedio naturale è indicato per la fluidità delle secrezioni bronchiali?',
#   'chunk_ids': [17],
#   'answer_example': 'TUX J 200ML, a base di sambuco e timo, è indicato per favorire la fluidità delle secrezioni bronchiali.',
#   'reasoning': 'Chunk 17 cita ingredienti ad azione balsamica e fluidificante.'},
#  {'question': 'Quale integratore può essere assunto per integrare magnesio, potassio e calcio?',
#   'chunk_ids': [41],
#   'answer_example': 'KEYMINERAL è un integratore alimentare che fornisce magnesio, potassio e calcio.',
#   'reasoning': 'Chunk 41 riporta queste indicazioni.'},
#  {'question': 'Quali integratori sono adatti per il metabolismo dei lipidi?',
#   'chunk_ids': [10, 45, 46],
#   'answer_example': 'Kiloburn Forte, Coleterol Act Plus Forte e Inverter Control P favoriscono il metabolismo lipidico tramite ingredienti come yerba mate, guggul e cassia nomame.',
#   'reasoning': 'I chunk 10, 45 e 46 riportano claim relativi al metabolismo lipidico.'},
#  {'question': "Come si può trattare in modo naturale l'insonnia o favorire il rilassamento?",
#   'chunk_ids': [20],
#   'answer_example': 'PULVISED contiene passiflora, escolzia e griffonia, utili per favorire rilassamento e regolare il sonno.',
#   'reasoning': 'Chunk 20 contiene formule vegetali per rilassamento e sonno.'},
#  {'question': 'Che integratore a base vegetale può aiutare la funzionalità digestiva?',
#   'chunk_ids': [10],
#   'answer_example': 'Kiloburn Forte contiene magnolia e opuntia, utili per la funzione digestiva e per favorire la digestione.',
#   'reasoning': 'Chunk 10 menziona funzioni digestive.'},
#  {'question': 'Quale prodotto contiene diosmina ed estratti di ippocastano per la circolazione?',
#   'chunk_ids': [6],
#   'answer_example': 'ERAVEN CREMA VASOTONICA contiene diosmina, insieme a estratti di ippocastano e altri componenti, per il benessere della circolazione.',
#   'reasoning': 'Chunk 6 elenca diosmina e ippocastano tra i componenti.'},
#  {'question': 'Quale prodotto è indicato come coadiuvante nel trattamento delle ipercromie cutanee?',
#   'chunk_ids': [39],
#   'answer_example': 'DISCROMIL PLUS CR è una crema schiarente indicata per risolvere rapidamente le ipercromie cutanee.',
#   'reasoning': 'Chunk 39 spiega l’indicazione schiarente sulle ipercromie.'},
#  {'question': "Per quali condizioni è sconsigliato l'utilizzo di Xalost*coll?",
#   'chunk_ids': [3],
#   'answer_example': 'Xalost non deve essere utilizzato in gravidanza, durante l’allattamento e in caso di ipersensibilità ai suoi componenti.',
#   'reasoning': 'Chunk 3 elenca le controindicazioni all’uso del farmaco.'},
#  {'question': 'Quale integratore contiene vitamina C ad alto dosaggio e palmitoiletanolamide?',
#   'chunk_ids': [29],
#   'answer_example': 'Sulfo24 30BUST contiene vitamina C (600 mg per dose) e palmitoiletanolamide.',
#   'reasoning': 'Chunk 29 formula integratore con questi principi.'},
#  {'question': 'Che prodotto è suggerito per lenire fastidi durante il ciclo mestruale in modo naturale?',
#   'chunk_ids': [5],
#   'answer_example': "Compressa Spa Mensile dona sollievo e benessere durante il ciclo mestruale grazie all'aloe vera calmante.",
#   'reasoning': 'Chunk 5 indirizzato al sollievo durante ciclo mestruale.'},
#  {'question': 'Quale prodotto per l’igiene intima contiene Tea Tree Oil?',
#   'chunk_ids': [15],
#   'answer_example': 'AMIDOSAN II NAT INTIMO PH ACID contiene Tea Tree Oil ed estratti di aloe e timo per detergere delicatamente le parti intime.',
#   'reasoning': 'Chunk 15 riporta tea tree oil tra gli ingredienti.'},
#  {'question': 'Che integratore può essere utile come supporto di aminoacidi essenziali e vitamine?',
#   'chunk_ids': [47],
#   'answer_example': 'RICOCELL 40CPR contiene vari aminoacidi essenziali, vitamina C, vitamina E e bioflavonoidi da agrumi.',
#   'reasoning': 'Chunk 47 definisce la presenza di aminoacidi e vitamine.'},
#  {'question': 'Cosa si può usare in caso di capelli con forfora?',
#   'chunk_ids': [18],
#   'answer_example': 'Lo Shampoo solido alla bardana è indicato per capelli con forfora grazie alle proprietà purificanti della bardana.',
#   'reasoning': 'Chunk 18 descrive uno shampoo specifico per questa condizione.'},
#  {'question': 'Esiste un prodotto consigliato per la protezione delle gengive e della placca orale?',
#   'chunk_ids': [33],
#   'answer_example': 'Il COLLUTTORIO PLUS è attivo contro la placca batterica e protegge efficacemente le gengive.',
#   'reasoning': 'Chunk 33 lo riporta come claim principale.'},
#  {'question': 'Quale rimedio vegetale sostiene il microcircolo oculare?',
#   'chunk_ids': [24],
#   'answer_example': 'LVS 30S EUPHRASIA OFFICIN COMP è un integratore alimentare a base di estratti idroalcolici, utile per favorire il trofismo del microcircolo a livello oculare.',
#   'reasoning': 'Chunk 24 lo indica come scopo principale.'},
#  {'question': 'Che prodotto è adatto come sostituto del pane per chi soffre di celiachia?',
#   'chunk_ids': [22],
#   'answer_example': 'Le GALLETTE RISO sono prodotte senza glutine e sono adatte come sostituto del pane per celiaci.',
#   'reasoning': 'Chunk 22 riporta l’indicazione specifica.'},
#  {'question': 'Quale prodotto può essere usato dopo la detersione per idratare la pelle del viso?',
#   'chunk_ids': [16, 44],
#   'answer_example': 'Il tonico con Hamamelis e Ruscus o il Siero viso acido jaluronico possono essere usati dopo la detersione per idratare la pelle.',
#   'reasoning': 'Chunks 16 e 44 descrivono prodotti idratanti da utilizzare dopo la detersione.'},
#  {'question': 'Quale prodotto cosmetico offre una protezione solare elevata?',
#   'chunk_ids': [],
#   'answer_example': 'Non vi sono prodotti nella raccolta che offrano una protezione solare specifica.',
#   'reasoning': 'Nessuno dei chunk elenca protezione solare come claim.'},
#  {'question': 'Esiste un prodotto antiparassitario per uso veterinario nella collezione?',
#   'chunk_ids': [],
#   'answer_example': 'Nella lista dei prodotti fornita non ci sono antiparassitari veterinari.',
#   'reasoning': 'Esame di tutti i chunk e assenza di riferimenti veterinari o antiparassitari.'},
#  {'question': 'Quale medicinale è indicato per il trattamento di infezioni da candida vaginale?',
#   'chunk_ids': [],
#   'answer_example': 'Non ci sono prodotti nella lista specifici per il trattamento di infezioni da candida vaginale.',
#   'reasoning': 'Nessuno dei chunk parla di antimicotici o trattamenti per candida.'},
#  {'question': 'Quale integratore può essere consigliato per migliorare la memoria e la concentrazione?',
#   'chunk_ids': [],
#   'answer_example': 'Nessun prodotto della lista ha come claim il miglioramento della memoria o della concentrazione.',
#   'reasoning': 'Analisi di tutti i chunk senza trovare claim su memoria/concentrazione.'},
#  {'question': 'È presente un medicinale per la gestione dell’asma broncale?',
#   'chunk_ids': [],
#   'answer_example': 'Nessun medicinale per l’asma broncale è presente tra i prodotti disponibili.',
#   'reasoning': 'Non ci sono medicinali broncodilatatori o specifici per asma tra i chunk.'}]

# %%
from langsmith import Client
import os 
from dotenv import load_dotenv

load_dotenv()

client = Client(api_key=os.environ["LANGSMITH_API_KEY"])

dataset_name = "rag_evaluation_dataset"
dataset = client.create_dataset(
    dataset_name=dataset_name,
    description="Dataset for evaluating the RAG pipeline"
)

# %%
for item in json_output:
    client.create_example(
        dataset_id=dataset.id,
        inputs={"question": item['question']},
        outputs={
            "grounded_answer": item['answer_example'],
            "context_ids": item['chunk_ids'],
            "context": [qdrant_client.retrieve(collection_name="dataset_farmaci_2", ids=[id], with_payload=True)[0].payload['text'] for id in item['chunk_ids']]
        }
    )
