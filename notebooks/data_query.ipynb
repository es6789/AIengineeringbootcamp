# %%
from zeep import Client
from zeep.transports import Transport
from zeep.plugins import HistoryPlugin
import logging

# Set up logging to see the SOAP requests and responses
logging.basicConfig(level=logging.INFO)
logging.getLogger('zeep.transports.http').setLevel(logging.DEBUG)

# Create a history plugin to capture requests/responses
history = HistoryPlugin()

# WSDL endpoint
wsdl_url = 'https://webservices.farmadati.it/WS2S/FarmadatiItaliaWebServicesM1.svc?singleWsdl'

# Initialize the zeep client with history plugin
client = Client(wsdl=wsdl_url, plugins=[history])

# Authentication credentials
username = 'BDF21152683'
password = 'ulEYGKZpQ'

print(f"Client initialized with WSDL: {wsdl_url}")
print(f"Available services: {list(client.wsdl.services.keys())}")
print(f"Available operations: {list(client.service.__dir__())}")
# Out:
# Client initialized with WSDL: https://webservices.farmadati.it/WS2S/FarmadatiItaliaWebServicesM1.svc?singleWsdl
# Available services: ['FarmadatiItaliaWebServicesM1']
# Available operations: ['__class__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__get__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__self__', '__self_class__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__thisclass__', 'GetEnabledDataSet', 'GetSchemaDataSet', 'ExecuteQuery', 'GetUsageLog']

# %%
# Test with manual SOAP request
import requests
import xml.etree.ElementTree as ET

print("=== Testing with manual SOAP request ===")

# Define the missing variables
codice_set_dati = 'TS013'
page_n = 1
paging_n = 50

# Create the exact SOAP envelope you provided
soap_envelope = f'''<?xml version="1.0" encoding="UTF-8"?>
<soapenv:Envelope xmlns:soapenv="http://schemas.xmlsoap.org/soap/envelope/" 
                  xmlns:web="https://webservices.farmadati.it" 
                  xmlns:arr="http://schemas.microsoft.com/2003/10/Serialization/Arrays" 
                  xmlns:fdiw="http://schemas.datacontract.org/2004/07/FDIWebServices">
   <soapenv:Header/>
   <soapenv:Body>
      <web:ExecuteQuery>
         <web:Username>{username}</web:Username>
         <web:Password>{password}</web:Password>
         <web:CodiceSetDati>{codice_set_dati}</web:CodiceSetDati>
         <web:CampiDaEstrarre>
            <arr:string>FDI_T122</arr:string>
            <arr:string>FDI_T123</arr:string>
            <arr:string>FDI_T124</arr:string>
         </web:CampiDaEstrarre>
         <web:Filtri>
         </web:Filtri>
         <web:Ordinamento>
         </web:Ordinamento>
         <web:Distinct>false</web:Distinct>
         <web:Count>false</web:Count>
         <web:PageN>{page_n}</web:PageN>
         <web:PagingN>{paging_n}</web:PagingN>
      </web:ExecuteQuery>
   </soapenv:Body>
</soapenv:Envelope>'''

print("Manual SOAP request:")
print(soap_envelope)

# Send the request manually
try:
    headers = {
        'Content-Type': 'text/xml; charset=utf-8',
        'SOAPAction': 'https://webservices.farmadati.it/FarmadatiItaliaWebServicesM1/ExecuteQuery'
    }
    
    response_manual = requests.post(
        'https://webservices.farmadati.it/WS2S/FarmadatiItaliaWebServicesM1.svc',
        data=soap_envelope,
        headers=headers
    )
    
    print(f"Manual request status: {response_manual.status_code}")
    print(f"Manual request response: {response_manual.text}")
    
    
except Exception as e:
    print(f"Error with manual request: {e}")
# Out:
# === Testing with manual SOAP request ===
# Manual SOAP request:
# <?xml version="1.0" encoding="UTF-8"?>
# <soapenv:Envelope xmlns:soapenv="http://schemas.xmlsoap.org/soap/envelope/"
#                   xmlns:web="https://webservices.farmadati.it"
#                   xmlns:arr="http://schemas.microsoft.com/2003/10/Serialization/Arrays"
#                   xmlns:fdiw="http://schemas.datacontract.org/2004/07/FDIWebServices">
#    <soapenv:Header/>
#    <soapenv:Body>
#       <web:ExecuteQuery>
#          <web:Username>BDF21152683</web:Username>
#          <web:Password>ulEYGKZpQ</web:Password>
#          <web:CodiceSetDati>TS013</web:CodiceSetDati>
#          <web:CampiDaEstrarre>
#             <arr:string>FDI_T122</arr:string>
#             <arr:string>FDI_T123</arr:string>
#             <arr:string>FDI_T124</arr:string>
#          </web:CampiDaEstrarre>
#          <web:Filtri>
#          </web:Filtri>
#          <web:Ordinamento>
#          </web:Ordinamento>
#          <web:Distinct>false</web:Distinct>
#          <web:Count>false</web:Count>
#          <web:PageN>1</web:PageN>
#          <web:PagingN>50</web:PagingN>
#       </web:ExecuteQuery>
#    </soapenv:Body>
# </soapenv:Envelope>
# Manual request status: 200
# Manual request response: <s:Envelope xmlns:s="http://schemas.xmlsoap.org/soap/envelope/"><s:Body><ExecuteQueryResponse xmlns="https://webservices.farmadati.it"><ExecuteQueryResult xmlns:a="http://schemas.datacontract.org/2004/07/FDIWebServices" xmlns:i="http://www.w3.org/2001/XMLSchema-instance"><a:CodEsito>OK</a:CodEsito><a:DescEsito>OK</a:DescEsito><a:NumRecords>43</a:NumRecords><a:OutputValue>&lt;?xml version="1.0" encoding="UTF-8"?&gt;&#xD;
# &lt;TableResult&gt;&#xD;
#   &lt;Product&gt;&#xD;
#     &lt;FDI_T122&gt;1011&lt;/FDI_T122&gt;&#xD;
#     &lt;FDI_T123&gt;SPEC.MED.CON PRESCR.MEDICA&lt;/FDI_T123&gt;&#xD;
#     &lt;FDI_T124&gt;SPECIALITA' MEDICINALI CON PRESCRIZIONE MEDICA&lt;/FDI_T124&gt;&#xD;
#   &lt;/Product&gt;&#xD;
#   &lt;Product&gt;&#xD;
#     &lt;FDI_T122&gt;1021&lt;/FDI_T122&gt;&#xD;
#     &lt;FDI_T123&gt;SPEC.MED.SENZA PRES.MED. SOP&lt;/FDI_T123&gt;&#xD;
#     &lt;FDI_T124&gt;SPECIALITA' MEDICINALI SENZA OBBLIGO DI PRESCRIZIONE MEDICA  S.O.P.&lt;/FDI_T124&gt;&#xD;
#   &lt;/Product&gt;&#xD;
#   &lt;Product&gt;&#xD;
#     &lt;FDI_T122&gt;1041&lt;/FDI_T122&gt;&#xD;
#     &lt;FDI_T123&gt;SPEC.MED.DA BANCO&lt;/FDI_T123&gt;&#xD;
#     &lt;FDI_T124&gt;SPECIALITA' MEDICINALI DA BANCO O DI AUTOMEDICAZIONE&lt;/FDI_T124&gt;&#xD;
#   &lt;/Product&gt;&#xD;
#   &lt;Product&gt;&#xD;
#     &lt;FDI_T122&gt;1051&lt;/FDI_T122&gt;&#xD;
#     &lt;FDI_T123&gt;FARMAC.PREC.PROD.IND.-GENERICI&lt;/FDI_T123&gt;&#xD;
#     &lt;FDI_T124&gt;FARMACI PRECONFEZIONATI PRODOTTI INDUSTRIALMENTE - GENERICI&lt;/FDI_T124&gt;&#xD;
#   &lt;/Product&gt;&#xD;
#   &lt;Product&gt;&#xD;
#     &lt;FDI_T122&gt;1061&lt;/FDI_T122&gt;&#xD;
#     &lt;FDI_T123&gt;SPEC.MED.VET.CON PRESCR.MED.&lt;/FDI_T123&gt;&#xD;
#     &lt;FDI_T124&gt;SPECIALITA' MEDICINALI VETERINARIE CON PRESCRIZIONE MEDICA&lt;/FDI_T124&gt;&#xD;
#   &lt;/Product&gt;&#xD;
#   &lt;Product&gt;&#xD;
#     &lt;FDI_T122&gt;1071&lt;/FDI_T122&gt;&#xD;
#     &lt;FDI_T123&gt;SPEC.MED.VET.SENZA PRESCR.MED.&lt;/FDI_T123&gt;&#xD;
#     &lt;FDI_T124&gt;SPECIALITA' MEDICINALI VETERINARIE SENZA OBBLIGO DI PRESCRIZIONE MEDICA&lt;/FDI_T124&gt;&#xD;
#   &lt;/Product&gt;&#xD;
#   &lt;Product&gt;&#xD;
#     &lt;FDI_T122&gt;1081&lt;/FDI_T122&gt;&#xD;
#     &lt;FDI_T123&gt;MEDIC.VET.PREFABBRICATI&lt;/FDI_T123&gt;&#xD;
#     &lt;FDI_T124&gt;MEDICINALI VETERINARI PREFABBRICATI&lt;/FDI_T124&gt;&#xD;
#   &lt;/Product&gt;&#xD;
#   &lt;Product&gt;&#xD;
#     &lt;FDI_T122&gt;1091&lt;/FDI_T122&gt;&#xD;
#     &lt;FDI_T123&gt;PREMISCELE PER ALIMENTI MED.&lt;/FDI_T123&gt;&#xD;
#     &lt;FDI_T124&gt;PREMISCELE PER ALIMENTI MEDICAMENTOSI&lt;/FDI_T124&gt;&#xD;
#   &lt;/Product&gt;&#xD;
#   &lt;Product&gt;&#xD;
#     &lt;FDI_T122&gt;1111&lt;/FDI_T122&gt;&#xD;
#     &lt;FDI_T123&gt;PREP.GALENICHE MAG.ESTEMP.IND.&lt;/FDI_T123&gt;&#xD;
#     &lt;FDI_T124&gt;PREPARAZIONI GALENICHE MAGISTRALI ESTEMPORANEE INDIVIDUALI&lt;/FDI_T124&gt;&#xD;
#   &lt;/Product&gt;&#xD;
#   &lt;Product&gt;&#xD;
#     &lt;FDI_T122&gt;1121&lt;/FDI_T122&gt;&#xD;
#     &lt;FDI_T123&gt;PREP.GALENICI MAG.MULTIPLI&lt;/FDI_T123&gt;&#xD;
#     &lt;FDI_T124&gt;PREPARATI GALENICI MAGISTRALI MULTIPLI&lt;/FDI_T124&gt;&#xD;
#   &lt;/Product&gt;&#xD;
#   &lt;Product&gt;&#xD;
#     &lt;FDI_T122&gt;1131&lt;/FDI_T122&gt;&#xD;
#     &lt;FDI_T123&gt;SOSTANZE MATERIE PRIME USO LAB&lt;/FDI_T123&gt;&#xD;
#     &lt;FDI_T124&gt;SOSTANZE MATERIE PRIME PER USO DI LABORATORIO&lt;/FDI_T124&gt;&#xD;
#   &lt;/Product&gt;&#xD;
#   &lt;Product&gt;&#xD;
#     &lt;FDI_T122&gt;1141&lt;/FDI_T122&gt;&#xD;
#     &lt;FDI_T123&gt;SOSTANZE PRECONF. PER VENDITA&lt;/FDI_T123&gt;&#xD;
#     &lt;FDI_T124&gt;SOSTANZE PRECONFEZIONATE PER LA VENDITA  PRONTE PER L'USO&lt;/FDI_T124&gt;&#xD;
#   &lt;/Product&gt;&#xD;
#   &lt;Product&gt;&#xD;
#     &lt;FDI_T122&gt;1151&lt;/FDI_T122&gt;&#xD;
#     &lt;FDI_T123&gt;PRODOTTI OMEOPATICI&lt;/FDI_T123&gt;&#xD;
#     &lt;FDI_T124&gt;PRODOTTI OMEOPATICI&lt;/FDI_T124&gt;&#xD;
#   &lt;/Product&gt;&#xD;
#   &lt;Product&gt;&#xD;
#     &lt;FDI_T122&gt;1202&lt;/FDI_T122&gt;&#xD;
#     &lt;FDI_T123&gt;PRODOTTI AFFINI AI FARMACEUT.&lt;/FDI_T123&gt;&#xD;
#     &lt;FDI_T124&gt;PRODOTTI AFFINI AI FARMACEUTICI&lt;/FDI_T124&gt;&#xD;
#   &lt;/Product&gt;&#xD;
#   &lt;Product&gt;&#xD;
#     &lt;FDI_T122&gt;1212&lt;/FDI_T122&gt;&#xD;
#     &lt;FDI_T123&gt;ACQUE MINERALI&lt;/FDI_T123&gt;&#xD;
#     &lt;FDI_T124&gt;ACQUE MINERALI&lt;/FDI_T124&gt;&#xD;
#   &lt;/Product&gt;&#xD;
#   &lt;Product&gt;&#xD;
#     &lt;FDI_T122&gt